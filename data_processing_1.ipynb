# %%
import pandas as pd
import numpy as np

# %%
filepath = 'laptops.csv'
df = pd.read_csv(filepath)

# %%
df
# Out:
#                                                  title   price  \
# 0    HP 15s, AMD Ryzen 3 5300U, 15.6 inch(39.6cm) F...  39,990
# 1    Dell Vostro 3420 Laptop,12th Gen Intel Core i3...  41,990
# 2    Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...  44,490
# 3    HP 255 G8 Laptop with AMD Athlon Silver 3050U ...  26,999
# 4    Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...  33,639
# ..                                                 ...     ...
# 334  Dell Inspiron 3525 Laptop, AMD Ryzen R3-5425U,...  39,990
# 335  (Renewed) DELL Latitude 5490 Core i5 8th Gen L...  26,615
# 336  ASUS Vivobook S 14 Flip (2023), AMD Ryzen 5 75...  68,990
# 337  Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...  64,999
# 338  ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...  56,990
#
#                  rating
# 0                   NaN
# 1                   NaN
# 2    4.4 out of 5 stars
# 3                   NaN
# 4                   NaN
# ..                  ...
# 334                 NaN
# 335                 NaN
# 336                 NaN
# 337                 NaN
# 338                 NaN
#
# [339 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   339 non-null    object
#  1   price   331 non-null    object
#  2   rating  24 non-null     object
# dtypes: object(3)
# memory usage: 8.1+ KB

# %%
print(df.columns.tolist())
# Out:
# ['title', 'price', 'rating']

# %%
def clean_price_column(price):
    if isinstance(price, str):         # check if price variable is a string
        price = price.replace(',', '') # remove comma
        price = price.strip()          # remove whitespace
        if price.isnumeric():
            price = int(price)
            return price
        if len(price) == 0:
            return np.nan
    return price

# %%
clean_price_column('23,902')
# Out:
# 23902

# %%
df['cleaned_price'] = df['price'].apply(clean_price_column)

# %%
df
# Out:
#                                                  title   price  \
# 0    HP 15s, AMD Ryzen 3 5300U, 15.6 inch(39.6cm) F...  39,990
# 1    Dell Vostro 3420 Laptop,12th Gen Intel Core i3...  41,990
# 2    Honor MagicBook 14, AMD Ryzen 5 5500U 14-inch ...  44,490
# 3    HP 255 G8 Laptop with AMD Athlon Silver 3050U ...  26,999
# 4    Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...  33,639
# ..                                                 ...     ...
# 334  Dell Inspiron 3525 Laptop, AMD Ryzen R3-5425U,...  39,990
# 335  (Renewed) DELL Latitude 5490 Core i5 8th Gen L...  26,615
# 336  ASUS Vivobook S 14 Flip (2023), AMD Ryzen 5 75...  68,990
# 337  Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...  64,999
# 338  ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...  56,990
#
#                  rating  cleaned_price
# 0                   NaN        39990.0
# 1                   NaN        41990.0
# 2    4.4 out of 5 stars        44490.0
# 3                   NaN        26999.0
# 4                   NaN        33639.0
# ..                  ...            ...
# 334                 NaN        39990.0
# 335                 NaN        26615.0
# 336                 NaN        68990.0
# 337                 NaN        64999.0
# 338                 NaN        56990.0
#
# [339 rows x 4 columns]

# %%
def clean_rating_column(rating):
    if isinstance(rating, str):
        rating = rating.split()[0]
        return float(rating)
    return rating

# %%
df['cleaned_rating'] = df['rating'].apply(clean_rating_column)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           339 non-null    object
#  1   price           331 non-null    object
#  2   rating          24 non-null     object
#  3   cleaned_price   331 non-null    float64
#  4   cleaned_rating  24 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 13.4+ KB

# %%
df.sort_values(by='cleaned_rating', ascending=False, inplace=True)
df
# Out:
#                                                  title     price  \
# 275  Apple 2021 MacBook Pro (16-inch/41.05 cm, M1 M...  3,19,990
# 18   Apple 2020 MacBook Air Laptop M1 chip, 13.3-in...    84,990
# 101  Apple 2020 MacBook Air Laptop M1 chip, 13.3-in...    84,990
# 230  ASUS Vivobook 15, Intel Core i3-1220P 12th Gen...    42,990
# 79   ASUS ROG Strix G17, 17.3-inch (43.94 cms) FHD ...    90,990
# ..                                                 ...       ...
# 66   Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...    64,999
# 99   Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...    64,999
# 188  Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...    64,999
# 293  Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...    64,999
# 194  Xioami NotebookUltra 3.2K Resolution Display I...    58,999
#
#                  rating  cleaned_price  cleaned_rating
# 275  4.7 out of 5 stars       319990.0             4.7
# 18   4.7 out of 5 stars        84990.0             4.7
# 101  4.7 out of 5 stars        84990.0             4.7
# 230  4.6 out of 5 stars        42990.0             4.6
# 79   4.5 out of 5 stars        90990.0             4.5
# ..                  ...            ...             ...
# 66                  NaN        64999.0             NaN
# 99                  NaN        64999.0             NaN
# 188                 NaN        64999.0             NaN
# 293                 NaN        64999.0             NaN
# 194                 NaN        58999.0             NaN
#
# [339 rows x 5 columns]

# %%
df.drop(columns=['price'], inplace=True)

# %%
df
# Out:
#                                                  title              rating  \
# 275  Apple 2021 MacBook Pro (16-inch/41.05 cm, M1 M...  4.7 out of 5 stars
# 18   Apple 2020 MacBook Air Laptop M1 chip, 13.3-in...  4.7 out of 5 stars
# 101  Apple 2020 MacBook Air Laptop M1 chip, 13.3-in...  4.7 out of 5 stars
# 230  ASUS Vivobook 15, Intel Core i3-1220P 12th Gen...  4.6 out of 5 stars
# 79   ASUS ROG Strix G17, 17.3-inch (43.94 cms) FHD ...  4.5 out of 5 stars
# ..                                                 ...                 ...
# 66   Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...                 NaN
# 99   Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...                 NaN
# 188  Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...                 NaN
# 293  Xiaomi NoteBook Pro 120 12th Gen Intel i5-1245...                 NaN
# 194  Xioami NotebookUltra 3.2K Resolution Display I...                 NaN
#
#      cleaned_price  cleaned_rating
# 275       319990.0             4.7
# 18         84990.0             4.7
# 101        84990.0             4.7
# 230        42990.0             4.6
# 79         90990.0             4.5
# ..             ...             ...
# 66         64999.0             NaN
# 99         64999.0             NaN
# 188        64999.0             NaN
# 293        64999.0             NaN
# 194        58999.0             NaN
#
# [339 rows x 4 columns]
